# %% [markdown]
# # DeepEval Commentary Analysis
#
# Анализ качества шахматных комментариев по метрикам deepeval.
# Поддерживает сравнение нескольких файлов (конфигураций).

# %%
from __future__ import annotations
import json
from pathlib import Path

import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as mticker
import seaborn as sns
import numpy as np

sns.set_theme(style="whitegrid", palette="muted")
plt.rcParams["figure.dpi"] = 120

RESULTS_DIR = Path("results")

# %% [markdown]
# ## 1. Выбор файлов для анализа
#
# Укажи файлы и человекочитаемые метки конфигураций в `FILES`.
# Можно один файл или несколько для сравнения.

# %%
# ── Настройка ────────────────────────────────────────────────────────────────
# Ключ = метка конфигурации (появится на графиках)
# Значение = путь к .jsonl файлу
FILES: dict[str, str] = {
    "baseline": "results/deepeval_config_full_think_off.jsonl",
    "gemma_system_instruct_fix": "results/deepeval_20260521_223304.jsonl",
    "gemma_baseline": "results/deepeval_20260521_222247.jsonl",
    "qwen_full_new_metrics": "results/deepeval_20260521_215126.jsonl",
    "qwen_full": "results/deepeval_20260521_213504.jsonl",
    "haiku_new_metrcs": "results/deepeval_20260521_204437.jsonl",
    "haiku": "results/deepeval_20260521_200926.jsonl",
    "alexander_off": "results/deepeval_20260521_140609.jsonl",
    "think_off_makogonov_off_tresholds_strict": "results/deepeval_20260521_133107.jsonl",
    "think_on": "results/deepeval_20260521_125422.jsonl",
    
}

# Фильтр по game_id (None = все игры)
GAME_FILTER: str | None = None  # например: "eval_trace_1779275077"
# ─────────────────────────────────────────────────────────────────────────────

# %%
def load_jsonl(path: str | Path) -> list[dict]:
    records = []
    with open(path, encoding="utf-8") as f:
        for line in f:
            line = line.strip()
            if line:
                records.append(json.loads(line))
    return records


def build_df(records: list[dict], label: str) -> pd.DataFrame:
    rows = []
    for r in records:
        base = {
            "run": label,
            "trace_id": r["trace_id"],
            "game_id": r["game_id"],
            "move_number": r["move_number"],
            "san": r["san"],
            "color": r.get("color", "unknown"),
            "quality": r.get("quality", "unknown"),
            "overall_pass": r["overall_pass"],
            "commentary": r.get("commentary", ""),
        }
        for m in r.get("metrics", []):
            # strip " [GEval]" suffix for short names
            name = m["name"].replace(" [GEval]", "").replace(" ", "_")
            base[f"score_{name}"] = m["score"]
            base[f"pass_{name}"] = m["success"]
            base[f"reason_{name}"] = m.get("reason", "")
        rows.append(base)
    return pd.DataFrame(rows)


dfs: dict[str, pd.DataFrame] = {}
for label, path in FILES.items():
    records = load_jsonl(path)
    df = build_df(records, label)
    if GAME_FILTER:
        df = df[df["game_id"] == GAME_FILTER]
    dfs[label] = df
    print(f"{label}: {len(df)} записей, игры: {df['game_id'].nunique()}")

all_df = pd.concat(dfs.values(), ignore_index=True)
SCORE_COLS = [c for c in all_df.columns if c.startswith("score_")]
METRIC_NAMES = [c.replace("score_", "") for c in SCORE_COLS]
print(f"\nМетрики: {METRIC_NAMES}")
# Out:
# baseline: 127 записей, игры: 1
# gemma_baseline: 16 записей, игры: 1
# qwen_full_new_metrics: 52 записей, игры: 1
# qwen_full: 21 записей, игры: 1
# haiku_new_metrcs: 52 записей, игры: 1
# haiku: 52 записей, игры: 1
# alexander_off: 31 записей, игры: 1
# think_off_makogonov_off_tresholds_strict: 52 записей, игры: 1
# think_on: 52 записей, игры: 1
#
# Метрики: ['Accuracy', 'ConceptualDepth', 'InputCoverage', 'HallucinationControl']

# %% [markdown]
# ## 2. Сводная таблица по конфигурациям

# %%
summary_rows = []
for label, df in dfs.items():
    row = {"run": label, "traces": len(df), "pass_rate": df["overall_pass"].mean()}
    for col in SCORE_COLS:
        if col in df.columns:
            row[col.replace("score_", "")] = df[col].mean()
    summary_rows.append(row)

summary = pd.DataFrame(summary_rows).set_index("run")
metric_cols = [c for c in summary.columns if c not in ("traces", "pass_rate")]

display(
    summary.style
    .format({"pass_rate": "{:.1%}", **{c: "{:.3f}" for c in metric_cols}})
    .background_gradient(subset=metric_cols, cmap="RdYlGn", vmin=0, vmax=1)
    .background_gradient(subset=["pass_rate"], cmap="RdYlGn", vmin=0, vmax=1)
    .set_caption("Средние оценки по метрикам (выше = лучше)")
)
# Out:
# <style type="text/css">
# #T_15cc8_row0_col1, #T_15cc8_row1_col1, #T_15cc8_row2_col1, #T_15cc8_row3_col1, #T_15cc8_row6_col1, #T_15cc8_row7_col1, #T_15cc8_row8_col1 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_15cc8_row0_col2, #T_15cc8_row7_col4 {
#   background-color: #f46d43;
#   color: #f1f1f1;
# }
# #T_15cc8_row0_col3 {
#   background-color: #e44c34;
#   color: #f1f1f1;
# }
# #T_15cc8_row0_col4 {
#   background-color: #f7814c;
#   color: #f1f1f1;
# }
# #T_15cc8_row0_col5 {
#   background-color: #f47044;
#   color: #f1f1f1;
# }
# #T_15cc8_row1_col2, #T_15cc8_row1_col5 {
#   background-color: #e95538;
#   color: #f1f1f1;
# }
# #T_15cc8_row1_col3 {
#   background-color: #f99153;
#   color: #000000;
# }
# #T_15cc8_row1_col4 {
#   background-color: #ec5c3b;
#   color: #f1f1f1;
# }
# #T_15cc8_row2_col2, #T_15cc8_row8_col4 {
#   background-color: #f7844e;
#   color: #f1f1f1;
# }
# #T_15cc8_row2_col3, #T_15cc8_row2_col5 {
#   background-color: #f57748;
#   color: #f1f1f1;
# }
# #T_15cc8_row2_col4, #T_15cc8_row6_col4, #T_15cc8_row8_col5 {
#   background-color: #f57547;
#   color: #f1f1f1;
# }
# #T_15cc8_row3_col2, #T_15cc8_row3_col3, #T_15cc8_row6_col3, #T_15cc8_row6_col5 {
#   background-color: #ef633f;
#   color: #f1f1f1;
# }
# #T_15cc8_row3_col4 {
#   background-color: #f98e52;
#   color: #f1f1f1;
# }
# #T_15cc8_row3_col5, #T_15cc8_row6_col2 {
#   background-color: #f26841;
#   color: #f1f1f1;
# }
# #T_15cc8_row4_col1 {
#   background-color: #ca2427;
#   color: #f1f1f1;
# }
# #T_15cc8_row4_col2 {
#   background-color: #fece7c;
#   color: #000000;
# }
# #T_15cc8_row4_col3 {
#   background-color: #fee593;
#   color: #000000;
# }
# #T_15cc8_row4_col4 {
#   background-color: #fffab6;
#   color: #000000;
# }
# #T_15cc8_row4_col5 {
#   background-color: #fafdb8;
#   color: #000000;
# }
# #T_15cc8_row5_col1 {
#   background-color: #b71126;
#   color: #f1f1f1;
# }
# #T_15cc8_row5_col2 {
#   background-color: #fee28f;
#   color: #000000;
# }
# #T_15cc8_row5_col3 {
#   background-color: #fecc7b;
#   color: #000000;
# }
# #T_15cc8_row5_col4 {
#   background-color: #fff5ae;
#   color: #000000;
# }
# #T_15cc8_row5_col5 {
#   background-color: #fff6b0;
#   color: #000000;
# }
# #T_15cc8_row7_col2, #T_15cc8_row7_col5 {
#   background-color: #ed5f3c;
#   color: #f1f1f1;
# }
# #T_15cc8_row7_col3 {
#   background-color: #ea5739;
#   color: #f1f1f1;
# }
# #T_15cc8_row8_col2 {
#   background-color: #f36b42;
#   color: #f1f1f1;
# }
# #T_15cc8_row8_col3 {
#   background-color: #f16640;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_15cc8">
#   <caption>Средние оценки по метрикам (выше = лучше)</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_15cc8_level0_col0" class="col_heading level0 col0" >traces</th>
#       <th id="T_15cc8_level0_col1" class="col_heading level0 col1" >pass_rate</th>
#       <th id="T_15cc8_level0_col2" class="col_heading level0 col2" >Accuracy</th>
#       <th id="T_15cc8_level0_col3" class="col_heading level0 col3" >ConceptualDepth</th>
#       <th id="T_15cc8_level0_col4" class="col_heading level0 col4" >InputCoverage</th>
#       <th id="T_15cc8_level0_col5" class="col_heading level0 col5" >HallucinationControl</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >run</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_15cc8_level0_row0" class="row_heading level0 row0" >baseline</th>
#       <td id="T_15cc8_row0_col0" class="data row0 col0" >127</td>
#       <td id="T_15cc8_row0_col1" class="data row0 col1" >0.0%</td>
#       <td id="T_15cc8_row0_col2" class="data row0 col2" >0.202</td>
#       <td id="T_15cc8_row0_col3" class="data row0 col3" >0.146</td>
#       <td id="T_15cc8_row0_col4" class="data row0 col4" >0.231</td>
#       <td id="T_15cc8_row0_col5" class="data row0 col5" >0.206</td>
#     </tr>
#     <tr>
#       <th id="T_15cc8_level0_row1" class="row_heading level0 row1" >gemma_baseline</th>
#       <td id="T_15cc8_row1_col0" class="data row1 col0" >16</td>
#       <td id="T_15cc8_row1_col1" class="data row1 col1" >0.0%</td>
#       <td id="T_15cc8_row1_col2" class="data row1 col2" >0.163</td>
#       <td id="T_15cc8_row1_col3" class="data row1 col3" >0.256</td>
#       <td id="T_15cc8_row1_col4" class="data row1 col4" >0.175</td>
#       <td id="T_15cc8_row1_col5" class="data row1 col5" >0.163</td>
#     </tr>
#     <tr>
#       <th id="T_15cc8_level0_row2" class="row_heading level0 row2" >qwen_full_new_metrics</th>
#       <td id="T_15cc8_row2_col0" class="data row2 col0" >52</td>
#       <td id="T_15cc8_row2_col1" class="data row2 col1" >0.0%</td>
#       <td id="T_15cc8_row2_col2" class="data row2 col2" >0.235</td>
#       <td id="T_15cc8_row2_col3" class="data row2 col3" >0.215</td>
#       <td id="T_15cc8_row2_col4" class="data row2 col4" >0.213</td>
#       <td id="T_15cc8_row2_col5" class="data row2 col5" >0.215</td>
#     </tr>
#     <tr>
#       <th id="T_15cc8_level0_row3" class="row_heading level0 row3" >qwen_full</th>
#       <td id="T_15cc8_row3_col0" class="data row3 col0" >21</td>
#       <td id="T_15cc8_row3_col1" class="data row3 col1" >0.0%</td>
#       <td id="T_15cc8_row3_col2" class="data row3 col2" >0.186</td>
#       <td id="T_15cc8_row3_col3" class="data row3 col3" >0.186</td>
#       <td id="T_15cc8_row3_col4" class="data row3 col4" >0.252</td>
#       <td id="T_15cc8_row3_col5" class="data row3 col5" >0.195</td>
#     </tr>
#     <tr>
#       <th id="T_15cc8_level0_row4" class="row_heading level0 row4" >haiku_new_metrcs</th>
#       <td id="T_15cc8_row4_col0" class="data row4 col0" >52</td>
#       <td id="T_15cc8_row4_col1" class="data row4 col1" >7.7%</td>
#       <td id="T_15cc8_row4_col2" class="data row4 col2" >0.365</td>
#       <td id="T_15cc8_row4_col3" class="data row4 col3" >0.417</td>
#       <td id="T_15cc8_row4_col4" class="data row4 col4" >0.483</td>
#       <td id="T_15cc8_row4_col5" class="data row4 col5" >0.513</td>
#     </tr>
#     <tr>
#       <th id="T_15cc8_level0_row5" class="row_heading level0 row5" >haiku</th>
#       <td id="T_15cc8_row5_col0" class="data row5 col0" >52</td>
#       <td id="T_15cc8_row5_col1" class="data row5 col1" >3.8%</td>
#       <td id="T_15cc8_row5_col2" class="data row5 col2" >0.410</td>
#       <td id="T_15cc8_row5_col3" class="data row5 col3" >0.362</td>
#       <td id="T_15cc8_row5_col4" class="data row5 col4" >0.467</td>
#       <td id="T_15cc8_row5_col5" class="data row5 col5" >0.469</td>
#     </tr>
#     <tr>
#       <th id="T_15cc8_level0_row6" class="row_heading level0 row6" >alexander_off</th>
#       <td id="T_15cc8_row6_col0" class="data row6 col0" >31</td>
#       <td id="T_15cc8_row6_col1" class="data row6 col1" >0.0%</td>
#       <td id="T_15cc8_row6_col2" class="data row6 col2" >0.194</td>
#       <td id="T_15cc8_row6_col3" class="data row6 col3" >0.184</td>
#       <td id="T_15cc8_row6_col4" class="data row6 col4" >0.213</td>
#       <td id="T_15cc8_row6_col5" class="data row6 col5" >0.187</td>
#     </tr>
#     <tr>
#       <th id="T_15cc8_level0_row7" class="row_heading level0 row7" >think_off_makogonov_off_tresholds_strict</th>
#       <td id="T_15cc8_row7_col0" class="data row7 col0" >52</td>
#       <td id="T_15cc8_row7_col1" class="data row7 col1" >0.0%</td>
#       <td id="T_15cc8_row7_col2" class="data row7 col2" >0.177</td>
#       <td id="T_15cc8_row7_col3" class="data row7 col3" >0.167</td>
#       <td id="T_15cc8_row7_col4" class="data row7 col4" >0.200</td>
#       <td id="T_15cc8_row7_col5" class="data row7 col5" >0.177</td>
#     </tr>
#     <tr>
#       <th id="T_15cc8_level0_row8" class="row_heading level0 row8" >think_on</th>
#       <td id="T_15cc8_row8_col0" class="data row8 col0" >52</td>
#       <td id="T_15cc8_row8_col1" class="data row8 col1" >0.0%</td>
#       <td id="T_15cc8_row8_col2" class="data row8 col2" >0.198</td>
#       <td id="T_15cc8_row8_col3" class="data row8 col3" >0.188</td>
#       <td id="T_15cc8_row8_col4" class="data row8 col4" >0.237</td>
#       <td id="T_15cc8_row8_col5" class="data row8 col5" >0.212</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## 3. Сравнение метрик по конфигурациям (radar + bar)

# %%
runs = list(dfs.keys())
colors = sns.color_palette("tab10", len(runs))

fig, axes = plt.subplots(1, 2, figsize=(16, 6))

# --- Bar chart ---
ax = axes[0]
x = np.arange(len(METRIC_NAMES))
width = 0.8 / max(len(runs), 1)
for i, (label, df) in enumerate(dfs.items()):
    means = [df[f"score_{m}"].mean() if f"score_{m}" in df.columns else 0 for m in METRIC_NAMES]
    ax.bar(x + i * width - width * (len(runs) - 1) / 2, means,
           width=width * 0.9, label=label, color=colors[i], alpha=0.85)
ax.set_xticks(x)
ax.set_xticklabels(METRIC_NAMES, rotation=35, ha="right", fontsize=9)
ax.set_ylim(0, 1)
ax.axhline(0.5, color="red", ls="--", lw=1, label="threshold 0.5")
ax.set_title("Средний балл по метрикам")
ax.legend(fontsize=8)
ax.yaxis.set_major_formatter(mticker.PercentFormatter(xmax=1))

# --- Radar chart ---
ax2 = axes[1]
N = len(METRIC_NAMES)
angles = [n / float(N) * 2 * np.pi for n in range(N)]
angles += angles[:1]

ax2 = plt.subplot(122, polar=True)
ax2.set_theta_offset(np.pi / 2)
ax2.set_theta_direction(-1)
ax2.set_xticks(angles[:-1])
ax2.set_xticklabels(METRIC_NAMES, size=8)
ax2.set_ylim(0, 1)
ax2.set_yticks([0.25, 0.5, 0.75, 1.0])
ax2.set_yticklabels(["0.25", "0.50", "0.75", "1.0"], size=7)

for i, (label, df) in enumerate(dfs.items()):
    values = [df[f"score_{m}"].mean() if f"score_{m}" in df.columns else 0 for m in METRIC_NAMES]
    values += values[:1]
    ax2.plot(angles, values, linewidth=2, color=colors[i], label=label)
    ax2.fill(angles, values, alpha=0.1, color=colors[i])
ax2.legend(loc="upper right", bbox_to_anchor=(1.35, 1.1), fontsize=8)
ax2.set_title("Radar", pad=15)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 4. Распределение оценок по метрикам (box plot)

# %%
rows_long = []
for label, df in dfs.items():
    for m in METRIC_NAMES:
        col = f"score_{m}"
        if col in df.columns:
            for v in df[col].dropna():
                rows_long.append({"run": label, "metric": m, "score": v})
long_df = pd.DataFrame(rows_long)

fig, ax = plt.subplots(figsize=(14, 6))
sns.boxplot(
    data=long_df, x="metric", y="score", hue="run",
    palette="tab10", linewidth=0.8, fliersize=3, ax=ax
)
ax.axhline(0.5, color="red", ls="--", lw=1.2, label="threshold 0.5")
ax.set_xticklabels(ax.get_xticklabels(), rotation=35, ha="right")
ax.set_ylim(-0.05, 1.05)
ax.set_title("Распределение оценок по метрикам")
ax.legend(title="run", fontsize=8)
plt.tight_layout()
plt.show()
# Out:
# /var/folders/v7/jd9nwf555hqg15pmncp612mc0000gn/T/ipykernel_79747/199083934.py:16: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=35, ha="right")

# %% [markdown]
# ## 5. Pass Rate по качеству хода (quality) и цвету

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

for ax, group_col, title in [
    (axes[0], "quality", "Pass Rate по качеству хода"),
    (axes[1], "color",   "Pass Rate по цвету"),
]:
    rows = []
    for label, df in dfs.items():
        gr = df.groupby(group_col)["overall_pass"].mean().reset_index()
        gr["run"] = label
        rows.append(gr)
    g = pd.concat(rows)
    sns.barplot(data=g, x=group_col, y="overall_pass", hue="run",
                palette="tab10", ax=ax)
    ax.set_ylim(0, 1)
    ax.axhline(0.5, color="red", ls="--", lw=1)
    ax.yaxis.set_major_formatter(mticker.PercentFormatter(xmax=1))
    ax.set_title(title)
    ax.legend(fontsize=8)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 6. Динамика оценок по номерам ходов

# %%
# Выбери метрику или 'overall_pass' для отображения
METRIC_FOR_TREND = METRIC_NAMES[0] if METRIC_NAMES else None

if METRIC_FOR_TREND:
    col = f"score_{METRIC_FOR_TREND}"
    fig, ax = plt.subplots(figsize=(14, 5))
    for i, (label, df) in enumerate(dfs.items()):
        if col not in df.columns:
            continue
        trend = df.groupby("move_number")[col].mean()
        ax.plot(trend.index, trend.values, marker="o", ms=4,
                label=label, color=colors[i])
    ax.axhline(0.5, color="red", ls="--", lw=1)
    ax.set_xlabel("Номер хода")
    ax.set_ylabel("Средний балл")
    ax.set_title(f"Динамика метрики '{METRIC_FOR_TREND}' по ходам партии")
    ax.legend(fontsize=8)
    plt.tight_layout()
    plt.show()
else:
    print("Нет метрик для отображения.")

# %% [markdown]
# ## 7. Тепловая карта средних оценок (конфигурация × метрика)

# %%
heat_data = {}
for label, df in dfs.items():
    heat_data[label] = {m: df[f"score_{m}"].mean() if f"score_{m}" in df.columns else np.nan
                        for m in METRIC_NAMES}

heat_df = pd.DataFrame(heat_data).T  # rows = runs, cols = metrics

fig, ax = plt.subplots(figsize=(max(10, len(METRIC_NAMES) * 1.3), max(3, len(dfs) * 1.2)))
sns.heatmap(
    heat_df, annot=True, fmt=".2f", cmap="RdYlGn",
    vmin=0, vmax=1, linewidths=0.5, ax=ax
)
ax.set_title("Средний балл: конфигурация × метрика")
ax.set_xlabel("")
ax.set_ylabel("")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 8. Худшие комментарии (для отладки)

# %%
# Показать N худших комментариев по avg score (для выбранного run'а)
TARGET_RUN = list(dfs.keys())[1]
TOP_N = 10

df = dfs[TARGET_RUN].copy()
df["avg_score"] = df[SCORE_COLS].mean(axis=1)
worst = df.nsmallest(TOP_N, "avg_score")[
    ["trace_id", "move_number", "san", "color", "quality", "avg_score", "overall_pass"] + SCORE_COLS
]

display(
    worst.style
    .format({"avg_score": "{:.3f}", **{c: "{:.2f}" for c in SCORE_COLS}})
    .background_gradient(subset=["avg_score"] + SCORE_COLS, cmap="RdYlGn", vmin=0, vmax=1)
    .set_caption(f"Топ-{TOP_N} худших комментариев ({TARGET_RUN})")
)
# Out:
# <style type="text/css">
# #T_b33b2_row0_col5, #T_b33b2_row0_col7, #T_b33b2_row0_col8, #T_b33b2_row0_col9, #T_b33b2_row0_col10, #T_b33b2_row1_col7, #T_b33b2_row1_col9, #T_b33b2_row1_col10, #T_b33b2_row2_col7, #T_b33b2_row2_col9, #T_b33b2_row2_col10, #T_b33b2_row3_col7, #T_b33b2_row3_col9, #T_b33b2_row3_col10, #T_b33b2_row4_col9, #T_b33b2_row4_col10, #T_b33b2_row5_col7, #T_b33b2_row5_col10, #T_b33b2_row6_col7, #T_b33b2_row6_col9 {
#   background-color: #d62f27;
#   color: #f1f1f1;
# }
# #T_b33b2_row1_col5, #T_b33b2_row2_col5, #T_b33b2_row3_col5 {
#   background-color: #de402e;
#   color: #f1f1f1;
# }
# #T_b33b2_row1_col8, #T_b33b2_row2_col8, #T_b33b2_row3_col8, #T_b33b2_row4_col7, #T_b33b2_row4_col8, #T_b33b2_row5_col8, #T_b33b2_row5_col9, #T_b33b2_row6_col8, #T_b33b2_row6_col10, #T_b33b2_row7_col5, #T_b33b2_row7_col7, #T_b33b2_row7_col8, #T_b33b2_row7_col9, #T_b33b2_row7_col10, #T_b33b2_row8_col5, #T_b33b2_row8_col7, #T_b33b2_row8_col8, #T_b33b2_row8_col9, #T_b33b2_row8_col10, #T_b33b2_row9_col5, #T_b33b2_row9_col7, #T_b33b2_row9_col8, #T_b33b2_row9_col9, #T_b33b2_row9_col10 {
#   background-color: #f46d43;
#   color: #f1f1f1;
# }
# #T_b33b2_row4_col5, #T_b33b2_row5_col5, #T_b33b2_row6_col5 {
#   background-color: #e54e35;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_b33b2">
#   <caption>Топ-10 худших комментариев (gemma_baseline)</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b33b2_level0_col0" class="col_heading level0 col0" >trace_id</th>
#       <th id="T_b33b2_level0_col1" class="col_heading level0 col1" >move_number</th>
#       <th id="T_b33b2_level0_col2" class="col_heading level0 col2" >san</th>
#       <th id="T_b33b2_level0_col3" class="col_heading level0 col3" >color</th>
#       <th id="T_b33b2_level0_col4" class="col_heading level0 col4" >quality</th>
#       <th id="T_b33b2_level0_col5" class="col_heading level0 col5" >avg_score</th>
#       <th id="T_b33b2_level0_col6" class="col_heading level0 col6" >overall_pass</th>
#       <th id="T_b33b2_level0_col7" class="col_heading level0 col7" >score_Accuracy</th>
#       <th id="T_b33b2_level0_col8" class="col_heading level0 col8" >score_ConceptualDepth</th>
#       <th id="T_b33b2_level0_col9" class="col_heading level0 col9" >score_InputCoverage</th>
#       <th id="T_b33b2_level0_col10" class="col_heading level0 col10" >score_HallucinationControl</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b33b2_level0_row0" class="row_heading level0 row0" >9</th>
#       <td id="T_b33b2_row0_col0" class="data row0 col0" >eval_trace_gemma_baseline__m5_Ne4_black_excellent</td>
#       <td id="T_b33b2_row0_col1" class="data row0 col1" >5</td>
#       <td id="T_b33b2_row0_col2" class="data row0 col2" >Ne4</td>
#       <td id="T_b33b2_row0_col3" class="data row0 col3" >black</td>
#       <td id="T_b33b2_row0_col4" class="data row0 col4" >excellent</td>
#       <td id="T_b33b2_row0_col5" class="data row0 col5" >0.100</td>
#       <td id="T_b33b2_row0_col6" class="data row0 col6" >False</td>
#       <td id="T_b33b2_row0_col7" class="data row0 col7" >0.10</td>
#       <td id="T_b33b2_row0_col8" class="data row0 col8" >0.10</td>
#       <td id="T_b33b2_row0_col9" class="data row0 col9" >0.10</td>
#       <td id="T_b33b2_row0_col10" class="data row0 col10" >0.10</td>
#     </tr>
#     <tr>
#       <th id="T_b33b2_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b33b2_row1_col0" class="data row1 col0" >eval_trace_gemma_baseline__m1_f5_black_good</td>
#       <td id="T_b33b2_row1_col1" class="data row1 col1" >1</td>
#       <td id="T_b33b2_row1_col2" class="data row1 col2" >f5</td>
#       <td id="T_b33b2_row1_col3" class="data row1 col3" >black</td>
#       <td id="T_b33b2_row1_col4" class="data row1 col4" >good</td>
#       <td id="T_b33b2_row1_col5" class="data row1 col5" >0.125</td>
#       <td id="T_b33b2_row1_col6" class="data row1 col6" >False</td>
#       <td id="T_b33b2_row1_col7" class="data row1 col7" >0.10</td>
#       <td id="T_b33b2_row1_col8" class="data row1 col8" >0.20</td>
#       <td id="T_b33b2_row1_col9" class="data row1 col9" >0.10</td>
#       <td id="T_b33b2_row1_col10" class="data row1 col10" >0.10</td>
#     </tr>
#     <tr>
#       <th id="T_b33b2_level0_row2" class="row_heading level0 row2" >5</th>
#       <td id="T_b33b2_row2_col0" class="data row2 col0" >eval_trace_gemma_baseline__m3_d5_black_best</td>
#       <td id="T_b33b2_row2_col1" class="data row2 col1" >3</td>
#       <td id="T_b33b2_row2_col2" class="data row2 col2" >d5</td>
#       <td id="T_b33b2_row2_col3" class="data row2 col3" >black</td>
#       <td id="T_b33b2_row2_col4" class="data row2 col4" >best</td>
#       <td id="T_b33b2_row2_col5" class="data row2 col5" >0.125</td>
#       <td id="T_b33b2_row2_col6" class="data row2 col6" >False</td>
#       <td id="T_b33b2_row2_col7" class="data row2 col7" >0.10</td>
#       <td id="T_b33b2_row2_col8" class="data row2 col8" >0.20</td>
#       <td id="T_b33b2_row2_col9" class="data row2 col9" >0.10</td>
#       <td id="T_b33b2_row2_col10" class="data row2 col10" >0.10</td>
#     </tr>
#     <tr>
#       <th id="T_b33b2_level0_row3" class="row_heading level0 row3" >7</th>
#       <td id="T_b33b2_row3_col0" class="data row3 col0" >eval_trace_gemma_baseline__m4_Nc6_black_excellent</td>
#       <td id="T_b33b2_row3_col1" class="data row3 col1" >4</td>
#       <td id="T_b33b2_row3_col2" class="data row3 col2" >Nc6</td>
#       <td id="T_b33b2_row3_col3" class="data row3 col3" >black</td>
#       <td id="T_b33b2_row3_col4" class="data row3 col4" >excellent</td>
#       <td id="T_b33b2_row3_col5" class="data row3 col5" >0.125</td>
#       <td id="T_b33b2_row3_col6" class="data row3 col6" >False</td>
#       <td id="T_b33b2_row3_col7" class="data row3 col7" >0.10</td>
#       <td id="T_b33b2_row3_col8" class="data row3 col8" >0.20</td>
#       <td id="T_b33b2_row3_col9" class="data row3 col9" >0.10</td>
#       <td id="T_b33b2_row3_col10" class="data row3 col10" >0.10</td>
#     </tr>
#     <tr>
#       <th id="T_b33b2_level0_row4" class="row_heading level0 row4" >2</th>
#       <td id="T_b33b2_row4_col0" class="data row4 col0" >eval_trace_gemma_baseline__m2_Nf3_white_best</td>
#       <td id="T_b33b2_row4_col1" class="data row4 col1" >2</td>
#       <td id="T_b33b2_row4_col2" class="data row4 col2" >Nf3</td>
#       <td id="T_b33b2_row4_col3" class="data row4 col3" >white</td>
#       <td id="T_b33b2_row4_col4" class="data row4 col4" >best</td>
#       <td id="T_b33b2_row4_col5" class="data row4 col5" >0.150</td>
#       <td id="T_b33b2_row4_col6" class="data row4 col6" >False</td>
#       <td id="T_b33b2_row4_col7" class="data row4 col7" >0.20</td>
#       <td id="T_b33b2_row4_col8" class="data row4 col8" >0.20</td>
#       <td id="T_b33b2_row4_col9" class="data row4 col9" >0.10</td>
#       <td id="T_b33b2_row4_col10" class="data row4 col10" >0.10</td>
#     </tr>
#     <tr>
#       <th id="T_b33b2_level0_row5" class="row_heading level0 row5" >3</th>
#       <td id="T_b33b2_row5_col0" class="data row5 col0" >eval_trace_gemma_baseline__m2_Nf6_black_best</td>
#       <td id="T_b33b2_row5_col1" class="data row5 col1" >2</td>
#       <td id="T_b33b2_row5_col2" class="data row5 col2" >Nf6</td>
#       <td id="T_b33b2_row5_col3" class="data row5 col3" >black</td>
#       <td id="T_b33b2_row5_col4" class="data row5 col4" >best</td>
#       <td id="T_b33b2_row5_col5" class="data row5 col5" >0.150</td>
#       <td id="T_b33b2_row5_col6" class="data row5 col6" >False</td>
#       <td id="T_b33b2_row5_col7" class="data row5 col7" >0.10</td>
#       <td id="T_b33b2_row5_col8" class="data row5 col8" >0.20</td>
#       <td id="T_b33b2_row5_col9" class="data row5 col9" >0.20</td>
#       <td id="T_b33b2_row5_col10" class="data row5 col10" >0.10</td>
#     </tr>
#     <tr>
#       <th id="T_b33b2_level0_row6" class="row_heading level0 row6" >15</th>
#       <td id="T_b33b2_row6_col0" class="data row6 col0" >eval_trace_gemma_baseline__m8_Qh4+_black_good</td>
#       <td id="T_b33b2_row6_col1" class="data row6 col1" >8</td>
#       <td id="T_b33b2_row6_col2" class="data row6 col2" >Qh4+</td>
#       <td id="T_b33b2_row6_col3" class="data row6 col3

# %%
best = df.nlargest(TOP_N, "avg_score")[
    ["trace_id", "move_number", "san", "color", "quality", "avg_score", "overall_pass"] + SCORE_COLS
]

display(
    best.style
    .format({"avg_score": "{:.3f}", **{c: "{:.2f}" for c in SCORE_COLS}})
    .background_gradient(subset=["avg_score"] + SCORE_COLS, cmap="RdYlGn", vmin=0, vmax=1)
    .set_caption(f"Топ-{TOP_N} лучших комментариев ({TARGET_RUN})")
)
# Out:
# <style type="text/css">
# #T_b90be_row0_col5 {
#   background-color: #fdc776;
#   color: #000000;
# }
# #T_b90be_row0_col7, #T_b90be_row0_col10, #T_b90be_row1_col7, #T_b90be_row1_col9, #T_b90be_row1_col10, #T_b90be_row2_col7, #T_b90be_row2_col9, #T_b90be_row2_col10, #T_b90be_row3_col7, #T_b90be_row3_col9, #T_b90be_row3_col10, #T_b90be_row4_col7, #T_b90be_row4_col9, #T_b90be_row4_col10, #T_b90be_row5_col7, #T_b90be_row5_col9, #T_b90be_row5_col10, #T_b90be_row6_col5, #T_b90be_row6_col7, #T_b90be_row6_col8, #T_b90be_row6_col9, #T_b90be_row6_col10, #T_b90be_row7_col5, #T_b90be_row7_col7, #T_b90be_row7_col8, #T_b90be_row7_col9, #T_b90be_row7_col10, #T_b90be_row8_col5, #T_b90be_row8_col7, #T_b90be_row8_col8, #T_b90be_row8_col9, #T_b90be_row8_col10, #T_b90be_row9_col8, #T_b90be_row9_col10 {
#   background-color: #f46d43;
#   color: #f1f1f1;
# }
# #T_b90be_row0_col8 {
#   background-color: #d9ef8b;
#   color: #000000;
# }
# #T_b90be_row0_col9, #T_b90be_row1_col8 {
#   background-color: #fee08b;
#   color: #000000;
# }
# #T_b90be_row1_col5 {
#   background-color: #f98e52;
#   color: #f1f1f1;
# }
# #T_b90be_row2_col5, #T_b90be_row3_col5, #T_b90be_row4_col5, #T_b90be_row5_col5 {
#   background-color: #f67c4a;
#   color: #f1f1f1;
# }
# #T_b90be_row2_col8, #T_b90be_row3_col8, #T_b90be_row4_col8, #T_b90be_row5_col8 {
#   background-color: #fdad60;
#   color: #000000;
# }
# #T_b90be_row9_col5 {
#   background-color: #e54e35;
#   color: #f1f1f1;
# }
# #T_b90be_row9_col7, #T_b90be_row9_col9 {
#   background-color: #d62f27;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_b90be">
#   <caption>Топ-10 лучших комментариев (gemma_baseline)</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b90be_level0_col0" class="col_heading level0 col0" >trace_id</th>
#       <th id="T_b90be_level0_col1" class="col_heading level0 col1" >move_number</th>
#       <th id="T_b90be_level0_col2" class="col_heading level0 col2" >san</th>
#       <th id="T_b90be_level0_col3" class="col_heading level0 col3" >color</th>
#       <th id="T_b90be_level0_col4" class="col_heading level0 col4" >quality</th>
#       <th id="T_b90be_level0_col5" class="col_heading level0 col5" >avg_score</th>
#       <th id="T_b90be_level0_col6" class="col_heading level0 col6" >overall_pass</th>
#       <th id="T_b90be_level0_col7" class="col_heading level0 col7" >score_Accuracy</th>
#       <th id="T_b90be_level0_col8" class="col_heading level0 col8" >score_ConceptualDepth</th>
#       <th id="T_b90be_level0_col9" class="col_heading level0 col9" >score_InputCoverage</th>
#       <th id="T_b90be_level0_col10" class="col_heading level0 col10" >score_HallucinationControl</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b90be_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b90be_row0_col0" class="data row0 col0" >eval_trace_gemma_baseline__m1_d4_white_good</td>
#       <td id="T_b90be_row0_col1" class="data row0 col1" >1</td>
#       <td id="T_b90be_row0_col2" class="data row0 col2" >d4</td>
#       <td id="T_b90be_row0_col3" class="data row0 col3" >white</td>
#       <td id="T_b90be_row0_col4" class="data row0 col4" >good</td>
#       <td id="T_b90be_row0_col5" class="data row0 col5" >0.350</td>
#       <td id="T_b90be_row0_col6" class="data row0 col6" >False</td>
#       <td id="T_b90be_row0_col7" class="data row0 col7" >0.20</td>
#       <td id="T_b90be_row0_col8" class="data row0 col8" >0.60</td>
#       <td id="T_b90be_row0_col9" class="data row0 col9" >0.40</td>
#       <td id="T_b90be_row0_col10" class="data row0 col10" >0.20</td>
#     </tr>
#     <tr>
#       <th id="T_b90be_level0_row1" class="row_heading level0 row1" >11</th>
#       <td id="T_b90be_row1_col0" class="data row1 col0" >eval_trace_gemma_baseline__m6_e6_black_best</td>
#       <td id="T_b90be_row1_col1" class="data row1 col1" >6</td>
#       <td id="T_b90be_row1_col2" class="data row1 col2" >e6</td>
#       <td id="T_b90be_row1_col3" class="data row1 col3" >black</td>
#       <td id="T_b90be_row1_col4" class="data row1 col4" >best</td>
#       <td id="T_b90be_row1_col5" class="data row1 col5" >0.250</td>
#       <td id="T_b90be_row1_col6" class="data row1 col6" >False</td>
#       <td id="T_b90be_row1_col7" class="data row1 col7" >0.20</td>
#       <td id="T_b90be_row1_col8" class="data row1 col8" >0.40</td>
#       <td id="T_b90be_row1_col9" class="data row1 col9" >0.20</td>
#       <td id="T_b90be_row1_col10" class="data row1 col10" >0.20</td>
#     </tr>
#     <tr>
#       <th id="T_b90be_level0_row2" class="row_heading level0 row2" >6</th>
#       <td id="T_b90be_row2_col0" class="data row2 col0" >eval_trace_gemma_baseline__m4_Bg5_white_excellent</td>
#       <td id="T_b90be_row2_col1" class="data row2 col1" >4</td>
#       <td id="T_b90be_row2_col2" class="data row2 col2" >Bg5</td>
#       <td id="T_b90be_row2_col3" class="data row2 col3" >white</td>
#       <td id="T_b90be_row2_col4" class="data row2 col4" >excellent</td>
#       <td id="T_b90be_row2_col5" class="data row2 col5" >0.225</td>
#       <td id="T_b90be_row2_col6" class="data row2 col6" >False</td>
#       <td id="T_b90be_row2_col7" class="data row2 col7" >0.20</td>
#       <td id="T_b90be_row2_col8" class="data row2 col8" >0.30</td>
#       <td id="T_b90be_row2_col9" class="data row2 col9" >0.20</td>
#       <td id="T_b90be_row2_col10" class="data row2 col10" >0.20</td>
#     </tr>
#     <tr>
#       <th id="T_b90be_level0_row3" class="row_heading level0 row3" >8</th>
#       <td id="T_b90be_row3_col0" class="data row3 col0" >eval_trace_gemma_baseline__m5_Qb3_white_excellent</td>
#       <td id="T_b90be_row3_col1" class="data row3 col1" >5</td>
#       <td id="T_b90be_row3_col2" class="data row3 col2" >Qb3</td>
#       <td id="T_b90be_row3_col3" class="data row3 col3" >white</td>
#       <td id="T_b90be_row3_col4" class="data row3 col4" >excellent</td>
#       <td id="T_b90be_row3_col5" class="data row3 col5" >0.225</td>
#       <td id="T_b90be_row3_col6" class="data row3 col6" >False</td>
#       <td id="T_b90be_row3_col7" class="data row3 col7" >0.20</td>
#       <td id="T_b90be_row3_col8" class="data row3 col8" >0.30</td>
#       <td id="T_b90be_row3_col9" class="data row3 col9" >0.20</td>
#       <td id="T_b90be_row3_col10" class="data row3 col10" >0.20</td>
#     </tr>
#     <tr>
#       <th id="T_b90be_level0_row4" class="row_heading level0 row4" >12</th>
#       <td id="T_b90be_row4_col0" class="data row4 col0" >eval_trace_gemma_baseline__m7_Ne5_white_inaccuracy</td>
#       <td id="T_b90be_row4_col1" class="data row4 col1" >7</td>
#       <td id="T_b90be_row4_col2" class="data row4 col2" >Ne5</td>
#       <td id="T_b90be_row4_col3" class="data row4 col3" >white</td>
#       <td id="T_b90be_row4_col4" class="data row4 col4" >inaccuracy</td>
#       <td id="T_b90be_row4_col5" class="data row4 col5" >0.225</td>
#       <td id="T_b90be_row4_col6" class="data row4 col6" >False</td>
#       <td id="T_b90be_row4_col7" class="data row4 col7" >0.20</td>
#       <td id="T_b90be_row4_col8" class="data row4 col8" >0.30</td>
#       <td id="T_b90be_row4_col9" class="data row4 col9" >0.20</td>
#       <td id="T_b90be_row4_col10" class="data row4 col10" >0.20</td>
#     </tr>
#     <tr>
#       <th id="T_b90be_level0_row5" class="row_heading level0 row5" >14</th>
#       <td id="T_b90be_row5_col0" class="data row5 col0" >eval_trace_gemma_baseline__m8_f3_white_best</td>
#       <td id="T_b90be_row5_col1" class="data row5 col1" >8</td>
#       <td id="T_b90be_row5_col2" class="data row5 col2" >f3</td>
#       <td id="T_b90be_row5_col3" class="data row5 col3" >white</td>
#       <td id="T_b90be_row5_col4" class="data row5 col4" >best</td>
#       <td id="T_b90be_row5_col5" class="data row5 col5" >0.225</td>
#       <td id="T_b90be_row5_col6" class="data row5 col6" >False</td>
#       <td id="T_b90be_row5_col7" class="data row5 col7" >0.20</td>
#       <td id="T_b90be_row5_col8" class="data row5 col8" >0.30</td>
#       <td id="T_b90be_row5_col9" class="data row5 col9" >0.20</td>
#       <td id="T_b90be_row5_col10" class="data row5 col10" >0.20</td>
#     </tr>
#     <tr>
#       <th id="T_b90be_level0_row6" class="row_heading level0 row6" >4</th>
#       <td id="T_b90be_row6_col0

# %% [markdown]
# ## 9. Детальный просмотр комментария

# %%
# Вставь trace_id для подробного разбора
INSPECT_TRACE = worst.iloc[0]["trace_id"] if not worst.empty else ""
INSPECT_RUN   = TARGET_RUN

row = dfs[INSPECT_RUN][dfs[INSPECT_RUN]["trace_id"] == INSPECT_TRACE]
if row.empty:
    print(f"Trace '{INSPECT_TRACE}' не найден в {INSPECT_RUN}")
else:
    row = row.iloc[0]
    print(f"=== {INSPECT_TRACE} ===")
    print(f"Move #{row['move_number']} {row['san']} ({row['color']}, {row['quality']})")
    print(f"Overall pass: {row['overall_pass']}\n")
    print("─── Commentary ───")
    print(row["commentary"])
    print()
    for m in METRIC_NAMES:
        score = row.get(f"score_{m}", "n/a")
        passed = row.get(f"pass_{m}", "?")
        reason = row.get(f"reason_{m}", "")
        status = "✅" if passed else "❌"
        print(f"{status} {m}: {score:.2f}" if isinstance(score, float) else f"{status} {m}: {score}")
        if reason:
            # wrap at ~100 chars
            import textwrap
            for line in textwrap.wrap(reason, 100):
                print(f"    {line}")
        print()
# Out:
# === eval_trace_gemma_baseline__m5_Ne4_black_excellent ===
# Move #5 Ne4 (black, excellent)
# Overall pass: False
#
# ─── Commentary ───
# Okay, here's a three-sentence commentary reflecting the provided context, focusing solely on the move Ne4 and its potential strategic implications:
#
# “White’s Ne4 immediately challenges Black’s central pawn structure, initiating a dynamic exchange that seeks to disrupt Black’s control of the center. This move suggests a desire for rapid development and a challenge to Black’s established pawn chain.  The position is currently relatively balanced, but Ne4 presents a significant opportunity for White to create an initiative and potentially steer the game towards an open, tactical battle.”
#
# ❌ Accuracy: 0.10
#     The response contains multiple critical errors. First, it attributes Ne4 to White when the input
#     explicitly states 'Black just played this move' and 'Our side: White.' Second, it fails to follow
#     the instruction to 'Stick to what the Context states'—it invents strategic ideas about 'challenging
#     Black's central pawn structure' and 'disrupting Black's control of the center' that are not
#     mentioned in the input. Third, it does not rephrase the context into exactly 3 commentary sentences
#     as instructed; instead it provides analysis that contradicts the given information. The response
#     also ignores the engine line details (bishop to h4, pawn to h6, pawn to e3) and the opening
#     classification provided. The only accurate element is acknowledging the position is balanced, but
#     this is insufficient given the fundamental misattribution of the move to the wrong side.
#
# ❌ ConceptualDepth: 0.10
#     The response fails to meet the evaluation criteria. It misidentifies the move as White's (the prompt
#     states Black played Ne4), fundamentally misunderstanding the position. The commentary lacks depth in
#     explaining WHY Ne4 is strategically sound—it uses vague phrases like 'dynamic exchange' and 'create
#     an initiative' without connecting to concrete strategic themes (development, center control, king
#     safety, piece activity). The output ignores the provided context entirely: it doesn't reference that
#     Ne4 matched the engine's top choice, doesn't explain how the move fits the Dutch Defense, and
#     doesn't acknowledge the engine's planned continuation (Bh4-h6-e3). The commentary reads as generic
#     positional analysis rather than grounded explanation of this specific move's merit.
#
# ❌ InputCoverage: 0.10
#     The response fails multiple evaluation criteria. It incorrectly attributes Ne4 to White when the
#     context explicitly states Black played the move. It does not acknowledge that Ne4 was the best move
#     (evaluation step 1). While it mentions the engine line exists, it doesn't incorporate the specific
#     engine recommendation of Bh4-h6-e3 (step 2). The commentary ignores the Dutch Defense opening
#     context and the historical background provided (step 4). The response also exceeds the requested
#     format by including an introductory sentence before the three commentary sentences. The strategic
#     analysis is generic and disconnected from the actual position evaluation of rough equality stated in
#     the context.
#
# ❌ HallucinationControl: 0.10
#     The output contains multiple critical errors. First, it misidentifies the move: the context states
#     'Black's knight moves to e4' but the commentary describes 'White's Ne4,' reversing the side making
#     the move. Second, the commentary invents strategic concepts ('challenges Black's central pawn
#     structure,' 'disrupt Black's control of the center,' 'challenge to Black's established pawn chain')
#     that do not appear in the input context. The input provides no information about pawn structures or
#     central control dynamics. Third, the output fails to incorporate the engine line (bishop to h4, pawn
#     to h6, pawn to e3) or acknowledge that Ne4 matched the engine's top choice, both explicitly stated
#     in the context. The commentary also exceeds the instruction to 'stick to what the Context states' by
#     adding interpretive analysis unsupported by the input. While the output does correctly note the
#     position is balanced, this alone cannot offset the fundamental misrepresentation of the move's
#     attribution and the invention of unstated strategic ideas.

# %% [markdown]
# ## 10. Дельта между конфигурациями (попарное сравнение)

# %%
if len(dfs) >= 2:
    run_names = list(dfs.keys())
    BASE_RUN = run_names[0]
    CMP_RUN  = run_names[1]

    base_means = {m: dfs[BASE_RUN][f"score_{m}"].mean() for m in METRIC_NAMES if f"score_{m}" in dfs[BASE_RUN].columns}
    cmp_means  = {m: dfs[CMP_RUN][f"score_{m}"].mean()  for m in METRIC_NAMES if f"score_{m}" in dfs[CMP_RUN].columns}

    deltas = {m: cmp_means.get(m, 0) - base_means.get(m, 0) for m in METRIC_NAMES}

    fig, ax = plt.subplots(figsize=(12, 4))
    x = np.arange(len(METRIC_NAMES))
    bar_colors = ["#2ecc71" if v >= 0 else "#e74c3c" for v in deltas.values()]
    ax.bar(x, list(deltas.values()), color=bar_colors, alpha=0.85)
    ax.axhline(0, color="black", lw=0.8)
    ax.set_xticks(x)
    ax.set_xticklabels(METRIC_NAMES, rotation=35, ha="right")
    ax.set_title(f"Дельта оценок: {CMP_RUN} − {BASE_RUN}  (зелёный = лучше)")
    ax.set_ylabel("Δ score")
    for xi, v in zip(x, deltas.values()):
        ax.text(xi, v + (0.005 if v >= 0 else -0.012), f"{v:+.3f}",
                ha="center", va="bottom" if v >= 0 else "top", fontsize=8)
    plt.tight_layout()
    plt.show()

    delta_pass = dfs[CMP_RUN]["overall_pass"].mean() - dfs[BASE_RUN]["overall_pass"].mean()
    print(f"Pass rate: {BASE_RUN}={dfs[BASE_RUN]['overall_pass'].mean():.1%}  "
          f"{CMP_RUN}={dfs[CMP_RUN]['overall_pass'].mean():.1%}  "
          f"Δ={delta_pass:+.1%}")
else:
    print("Добавь второй файл в FILES для сравнения.")
# Out:
# Pass rate: baseline=0.0%  gemma_baseline=0.0%  Δ=+0.0%

# %% [markdown]
# ## 11. Сравнение по общим trace_id (только общие ходы)

# %%
if len(dfs) >= 2:
    run_names = list(dfs.keys())
    BASE_RUN, CMP_RUN = run_names[0], run_names[1]
    common_ids = set(dfs[BASE_RUN]["trace_id"]) & set(dfs[CMP_RUN]["trace_id"])
    print(f"Общих trace_id: {len(common_ids)}")

    if common_ids:
        shared_rows = []
        for tid in sorted(common_ids):
            r_base = dfs[BASE_RUN][dfs[BASE_RUN]["trace_id"] == tid].iloc[0]
            r_cmp  = dfs[CMP_RUN][dfs[CMP_RUN]["trace_id"] == tid].iloc[0]
            row = {"trace_id": tid, "move_number": r_base["move_number"],
                   "san": r_base["san"], "quality": r_base["quality"]}
            for m in METRIC_NAMES:
                c = f"score_{m}"
                v_base = r_base.get(c, np.nan)
                v_cmp  = r_cmp.get(c, np.nan)
                row[f"{m}_base"] = v_base
                row[f"{m}_cmp"]  = v_cmp
                row[f"{m}_delta"] = v_cmp - v_base
            shared_rows.append(row)

        shared_df = pd.DataFrame(shared_rows).sort_values("move_number")
        delta_cols = [f"{m}_delta" for m in METRIC_NAMES]

        display(
            shared_df[["trace_id", "move_number", "san", "quality"] + delta_cols]
            .style
            .format({c: "{:+.2f}" for c in delta_cols})
            .background_gradient(subset=delta_cols, cmap="RdYlGn", vmin=-0.5, vmax=0.5)
            .set_caption(f"Δ score по общим ходам: {CMP_RUN} − {BASE_RUN}")
        )
else:
    print("Нужно минимум 2 конфигурации.")
# Out:
# Общих trace_id: 0
